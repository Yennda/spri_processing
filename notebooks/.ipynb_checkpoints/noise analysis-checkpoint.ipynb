# %%
import sys
sys.path.append('..')
# %matplotlib inline

import math as m
import numpy as np
import scipy.signal as signal

import matplotlib
import matplotlib.pyplot as plt
from core import Core

from global_var import COLORS

# %%
print(COLORS)
# COLORS.append('#44DD55')
# Out:
# ['#ffb200', '#0284C0', '#DD5544', '#008000', '#DD84C0', '#000000']

# %%
matplotlib.rc('font', family='serif') 
matplotlib.rc('font', serif='Palatino Linotype') 
matplotlib.rc('text', usetex='false') 
matplotlib.rcParams.update({'font.size': 20})

# %%
folder = r'C:\SPRUP_data_Jenda\2021_08_30_noise/'.replace('\\', '/')

for i in range(1,8):
    print(i)    
    name = 'raw_0{}_1'.format(i)
    core = Core(folder, name)
    core.k = 10

    core.type = 'raw'
    core_raw_std = [np.std(core.frame(i)) for i in range(len(core))]
    core_raw_int = [np.average(core.frame(i)) for i in range(len(core))]

    core.type = 'diff'
    core_diff_std = [np.std(core.frame(i)) for i in range(len(core))]
    core_diff_int = [np.average(np.abs(core.frame(i))) for i in range(len(core))]
    
    np.save(folder + name + '_raw_int' + '.npy', core_raw_int)
    np.save(folder + name + '_raw_std' + '.npy', core_raw_std)
    
    np.save(folder + name + '_diff_int' + '.npy', core_diff_int)
    np.save(folder + name + '_diff_std' + '.npy', core_diff_std)
    
    np.save(folder + name + '_time' + '.npy', core._time_info[:,0])
# Out:
# 1
# core 1: SPR file not found. Diseable ploting of SPR.

# %%
core.k
# Out:
# 1

# %%
folder = r'C:\SPRUP_data_Jenda\2021_08_30_noise/'.replace('\\', '/')

frame_time = [0.1047, 0.1308, 0.1308, 0.1002, 0.1003, 0.1046, 0.1305]
ets = [12.5, 5, 1, 25, 25, 12.5, 5]
avg = [8, 10, 10, 4, 4, 8, 10]
ma = [58.7, 60.7, 62.9, 56.0, 'SC', 'SC', 'SC']




raw_int = []
raw_std = []

diff_int = []
diff_std = []
std_time = []

for i in range(1,8):
    name = 'raw_0{}_1'.format(i)
    raw_int.append(np.load(folder + name + '_raw_int' + '.npy'))
    raw_std.append(np.load(folder + name + '_raw_std' + '.npy'))
    
    diff_std.append(np.load(folder + name + '_diff_std' + '.npy'))
    diff_int.append(np.load(folder + name + '_diff_int' + '.npy'))    
    
    std_time.append(np.load(folder + name + '_time' + '.npy'))

# %%
correction = [frame_time[i] / ets[i] / avg[i] * 1000 for i in range(7)]
intensity = [np.average(int_raw[i])*avg[i]*correction[i] for i in range(7)]

print(intensity)
# Out:
# [4.179262088862502, 13.812478152423974, 63.712424733830105, 2.0742198636713174, 1.8426805339520682, 1.936417921604508, 2.4075393975566537]

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 1, 1])
axes.grid(linestyle='--')

title = 'int_diff'
axes.set_title(title)
axes.set_xlabel('t [s]')
axes.set_ylabel('std [a. u.]')

for i in [3, 4]:

#     axes.plot(std_time[i], int_diff[i], linewidth=2, label = '{} ms x {}, {} mA'.format(ets[i], avg[i], ma[i]), color = COLORS[i])
    axes.plot(std_time[i], int_diff[i]/intensity[i], linewidth=2, label = '{} ms x {}, {} mA'.format(ets[i], avg[i], ma[i]), color = COLORS[i])

#     axes.plot(std_time[i][20:], std_diff[i][20:]*avg[i]*correction[i], linewidth=2, label = '{} ms x {}, {} mA'.format(ets[i], avg[i], ma[i]), color = COLORS[i])
#     axes.plot(std_time[i][20:], std_diff[i][20:]/intensity[i], linewidth=2, label = '{} ms x {}, {} mA'.format(ets[i], avg[i], ma[i]), color = COLORS[i])


# axes.plot(core._time_info[:,0], core_diff_std, linewidth=2)

# axes.set_ylim(np.min(core_std), np.max(core_std))

lgd = fig.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))

# fig.savefig(folder + title +'.png', dpi=300, bbox_extra_artists=(lgd,), bbox_inches='tight')
