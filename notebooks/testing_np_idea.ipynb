# %%
import sys
import cv2
import re
import csv
from PIL import Image

from skimage.feature import peak_local_max

from skspatial.objects import Points, Plane
from skspatial.plotting import plot_3d

from skimage.feature import blob_dog, blob_log, blob_doh
from skimage.color import rgb2gray

sys.path.append('..')

# %%
# %matplotlib notebook
import math as m
import numpy as np
from scipy import ndimage
from scipy.optimize import lsq_linear

import matplotlib
import matplotlib.pyplot as plt

from core import Core

from global_var import COLORS

# %%
matplotlib.rc('font', family='serif') 
matplotlib.rc('font', serif='Palatino Linotype') 
matplotlib.rc('text', usetex='false') 
matplotlib.rcParams.update({'font.size': 20})

# %%
folder = r'D:\SPRUP_data_Jenda\21_04_01_BC5\ideas/'.replace('\\', '/')
file = 'raw_02_'

folder = r'C:\SPRUP_data_Jenda\2019_03_13_Jenda_microscopy\20_12_11_BC5\ideas/'.replace('\\', '/')
file = 'raw_02_'

ideas = []

for i in range(1, 2):
    idea = np.load(folder + file + '{}.npy'.format(i))
    idea = np.abs(idea)
    ideas.append(idea)
    print(i)
    print('\tsum: {:.3f}'.format(np.sum(idea)))
    print('\tmax: {:.3f}'.format(np.max(idea)))
    print('\tmin: {:.3f}'.format(np.min(idea)))
    
    print('\tshape: {}'.format(idea.shape))
# Out:
# 1
# 	sum: 1.000
# 	max: 0.002
# 	min: 0.000
# 	shape: (12, 12, 20)

# %%
for idea in ideas:
    fig = plt.figure()
    axes = fig.add_axes([0.1, 0, 0.7, 0.9])
    axes.set_title(file)


    axes.imshow(
        idea[:,:,10],
        cmap='gray',
        zorder=0,
    )
# Out:
# <img src="data:image/png;base64,..." width="640">
