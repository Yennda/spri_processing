# %% [raw]
# https://currents.soest.hawaii.edu/ocn_data_analysis/_static/SEM_EDOF.html

# %%
import sys
sys.path.append('..')

# %%
# %matplotlib notebook

import math as m
import numpy as np
import scipy.signal as signal

import matplotlib
import matplotlib.pyplot as plt

from core import Core

from global_var import COLORS

# %%
matplotlib.rc('font', family='serif') 
matplotlib.rc('font', serif='Palatino Linotype') 
matplotlib.rc('text', usetex='false') 
matplotlib.rcParams.update({'font.size': 20})

# %%
well = 32700
average = 10

# %%
folder = r'D:\SPRUP_data_Jenda\21_04_14_DG750A1/'.replace('\\', '/')

file = 'raw_01_'
i = 3

c = Core(folder, file+str(i))
c.k = 10
c.type = 'diff'
c._data_raw = c._data_raw[:60, :200, :208]

# 100ms x 1

# %%
c_std = np.zeros(c.shape_img)

for i in range(c.shape_img[0]):
    for j in range(c.shape_img[1]):    
        c_std[i, j] = np.std(c._data_raw[i, j, :])

# %%
d_std = []
for f in range(20, len(c)):
    d_std.append(np.average(np.abs(c.frame(f))))

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 1, 1])
# d =  c._data_raw[:, :, 50]
d =  c_std[:, :]

axes.imshow(
    d,
    cmap='gray',
    zorder=0,
#     vmin=np.min(d)*0.2,
#     vmax=np.max(d)*0.2
)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
i_avg = np.average(c._data_raw)
print('px std: {}'.format(np.average(c_std)))
print('diff frame std: {}'.format(np.average(d_std)))
print('avg int: {}'.format(i_avg))
print('-'*20)
print('px std: {}'.format(np.average(c_std)/i_avg))
print('diff frame std: {}'.format(np.average(d_std)/i_avg))
# Out:
# px std: 0.0010645843058932228
# diff frame std: 0.00038030201378605634
# avg int: 0.1371577907802667
# --------------------
# px std: 0.0077617487117355045
# diff frame std: 0.002772733591162301

# %%
c.type = 'diff'
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 1, 1])

d =  c.frame(-1)
print(np.std(d))
print(np.average(d))
axes.imshow(
    d,
    cmap='gray',
    zorder=0,
#     vmin=np.min(d)*0.2,
#     vmax=np.max(d)*0.2
)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.05088575983346312
# -0.1370683959096459

# %%
folder = r'D:\SPRUP_data_Jenda\20_10_16_L3/'.replace('\\', '/')

file = 'raw_01_'
i = 3

c = Core(folder, file+str(i))
c.k = 10
c.type = 'diff'
c._data_raw = c._data_raw[:60, :200, :]*50

# 2 ms x 10

# %%
print(len(c))
# Out:
# 208

# %%
c_std = np.zeros(c.shape_img)
for i in range(c.shape_img[0]):
    for j in range(c.shape_img[1]):    
        c_std[i, j] = np.std(c._data_raw[i, j, :])

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 1, 1])
# d =  c._data_raw[:, :, 50]
d =  c_std[:, :]

axes.imshow(
    d,
    cmap='gray',
    zorder=0,
#     vmin=np.min(d)*0.2,
#     vmax=np.max(d)*0.2
)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
d_std = []
for f in range(20, len(c)):
    d_std.append(np.average(np.abs(c.frame(f))))

# %%
i_avg = np.average(c._data_raw)
print('px std: {}'.format(np.average(c_std)))
print('diff frame std: {}'.format(np.average(d_std)))
print('avg int: {}'.format(i_avg))
print('-'*20)
print('px std: {}'.format(np.average(c_std)/i_avg))
print('diff frame std: {}'.format(np.average(d_std)/i_avg))
# Out:
# px std: 0.11808815235394012
# diff frame std: 0.05591772313580825
# avg int: 23.79830230982516
# --------------------
# px std: 0.004962041023623238
# diff frame std: 0.002349651769602176

# %% [raw]
# px std: 0.0010645843058932228
# diff frame std: 0.00038030201378605634
# avg int: 0.1371577907802667
# --------------------
# px std: 0.0077617487117355045
# diff frame std: 0.002772733591162301

# %%
c.type = 'diff'
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 1, 1])

d =  c.frame(-1)
print(np.std(d))
print(np.average(d))
axes.imshow(
    d,
    cmap='gray',
    zorder=0,
#     vmin=np.min(d)*0.2,
#     vmax=np.max(d)*0.2
)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 3.802735506847591
# -23.79133310948311

# %%
0.08872478939265005
-0.23269690883190886
# Out:
# -0.23269690883190886
